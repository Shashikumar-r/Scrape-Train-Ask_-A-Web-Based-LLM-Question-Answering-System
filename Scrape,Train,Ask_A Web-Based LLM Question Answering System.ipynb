# %% [markdown]
# ### Scrap the html content from website

# %%
print('hello')

# %%
import requests
from bs4 import BeautifulSoup

website = requests.request(url="https://blog.londonappbrewery.com/how-a-doctor-ran-a-tech-startup-while-working-80-hour-weeks-d47e7b4988cb")
soup = BeautifulSoup(website,"html.parser")
print(soup.text)
